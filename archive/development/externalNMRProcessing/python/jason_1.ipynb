# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import platform
import h5py
import beautifuljason as bjason

# %%
if platform.system() == "Darwin":

    fn = Path("/Users/vsmw51/OneDrive - Durham University/projects/programming/2025/python/awh/bruker_data_sets/E72507_04164043_propyl_benzoate/04164043/04164043.jjh5")
    fn = Path("/opt/topspin4.5.0/examdata/exam_CMCse_1/alpha_ionone.jjh5")

# %%
fn.exists()
# Out:
# True

# %%
with bjason.Document(fn, mode='r') as doc:
    for pred_spec in doc.mol_data[0].spectra:
        print(f'Nucleus: {pred_spec.nucleus.name}')
        for shift in pred_spec.shifts:
            print(f'  Atoms: {shift.nums}, Shift: {shift.value[0]} ppm')
# Out:
# Nucleus: C13
#   Atoms: [0], Shift: 198.31080627441406 ppm
#   Atoms: [1], Shift: 148.9245147705078 ppm
#   Atoms: [4], Shift: 122.59451293945312 ppm
#   Atoms: [5], Shift: 54.248268127441406 ppm
#   Atoms: [2], Shift: 133.10081481933594 ppm
#   Atoms: [3], Shift: 132.65194702148438 ppm
#   Atoms: [6], Shift: 34.32792663574219 ppm
#   Atoms: [7], Shift: 34.607112884521484 ppm
#   Atoms: [8], Shift: 26.21915054321289 ppm
#   Atoms: [9], Shift: 27.899139404296875 ppm
#   Atoms: [10], Shift: 26.21915054321289 ppm
#   Atoms: [11], Shift: 22.827123641967773 ppm
#   Atoms: [12], Shift: 22.699148178100586 ppm
# Nucleus: H1
#   Atoms: [8], Shift: 0.8130199909210205 ppm
#   Atoms: [9], Shift: 2.033019542694092 ppm
#   Atoms: [10], Shift: 0.8130202293395996 ppm
#   Atoms: [12], Shift: 1.6030195951461792 ppm
#   Atoms: [1], Shift: 6.43302059173584 ppm
#   Atoms: [2], Shift: 6.103023529052734 ppm
#   Atoms: [4], Shift: 5.243020057678223 ppm
#   Atoms: [5], Shift: 2.6230196952819824 ppm
# ...

# %%
with bjason.Document(fn, mode='r') as doc:
    print(len(doc.nmr_data))
    print(dir(doc.nmr_data[1].peaks[0]))
    for pk in doc.nmr_data[1].peaks:
        print(f'Peak pos: {pk.pos}, Height: {pk.height}')
# Out:
# 6
# ['List', 'PeakClassification', 'PeakType', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'area', 'area_sigma', 'classification', 'h5_group', 'height', 'id', 'label', 'offset', 'pos', 'shape_par', 'type', 'width']
# Peak pos: [  6.59263    148.97472147   0.        ], Height: 507817839.0900242
# Peak pos: [  6.02824836 132.25041524   0.        ], Height: 477335105.58785844
# Peak pos: [  5.47703576 122.57274394   0.        ], Height: 546131474.536023
# Peak pos: [ 2.26069841 54.25952748  0.        ], Height: 633414401.8269935
# Peak pos: [ 2.23090547 26.9258866   0.        ], Height: 1518057502.3857646
# ...

# %%
with bjason.Document(fn, mode='r') as doc:
    print(dir(doc.nmr_data[0]))
# Out:
# ['List', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'h5_group', 'id', 'multiplets', 'ndim', 'peaks', 'proc_list', 'raw_data', 'spec_info']

# %%
with bjason.Document(fn, mode='r') as doc:
    print(dir(doc.nmr_data[1].peaks[0]))
# Out:
# ['List', 'PeakClassification', 'PeakType', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'area', 'area_sigma', 'classification', 'h5_group', 'height', 'id', 'label', 'offset', 'pos', 'shape_par', 'type', 'width']

# %%
# It is assumed that the 'example.jjh5' document contains a spectrum with multiplets.

with bjason.Document(fn, mode='r') as doc:
    for multiplet in doc.nmr_data[1].multiplets:
        print(f'Pos: {multiplet.pos[0]}, {multiplet.pos[1]}, Sum Integral: {multiplet.value_hz}')
# Out:
# Pos: 0.0, 0.0, Sum Integral: 942702108524.7856
# Pos: 0.0, 0.0, Sum Integral: 748485799528.8553
# Pos: 0.0, 0.0, Sum Integral: 725897407728.5333
# Pos: 0.0, 0.0, Sum Integral: 1035434419773.4674
# Pos: 0.0, 0.0, Sum Integral: 2315992564528.699
# Pos: 0.0, 0.0, Sum Integral: -3086411940167.9385
# Pos: 0.0, 0.0, Sum Integral: 2881917095594.7754
# Pos: 0.0, 0.0, Sum Integral: -797947920429.9164
# Pos: 0.0, 0.0, Sum Integral: -1067813700985.3809
# Pos: 0.0, 0.0, Sum Integral: 2578603999689.4443
# Pos: 0.0, 0.0, Sum Integral: 3694748557731.1475

# %%
with bjason.Document(fn, mode='r') as doc:
    nmr_item = doc.nmr_items[1]
    print(dir(nmr_item.spec_data_list[0].multiplets))
# Out:
# ['Iterator', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_len', 'append', 'auto_baseline', 'h5_group', 'id', 'integral_lvl', 'integral_scale', 'integral_scale_scoped', 'integral_tlt', 'integral_total', 'integral_vscale', 'integral_vshift', 'list_group_name', 'pos_units', 'value_class']

# %%
# It is assumed that the 'example.jjh5' document contains a spectrum.
with bjason.Document(fn, mode='r') as doc:
    for proc in doc.nmr_data[1].proc_list:
        print(f'Name: {proc.name}')
        for param in proc.parameters:
            print(f'  {param.name}({param.tip}): {param.value}')
# Out:
# Name: Shrink
#   Points kept(Number of complex data points to be kept): 256
#   Left shift(Left shift of data. Use negative values for right shift.): 0
# Name: Apodization
#   Exponential(Apply single-exponential apodization): False
#   (Width of the exponential): 0.0
#   Gauss(Apply Gauss apodization): False
#   (Width of the Gaussian): 0.0
#   Shift(Shift in time): 0.0
#   Sine(Apply sine apodization): True
#   Order(Order: 1 - sine, 2 - squared sine ): ['1', '2']
#   Shape(Shape: 1 - pure sine; 2 - pure cosine): 2.0
#   Trapezoid(): False
#   (Start of the trapezoid): 0.0
#   (1st top of the trapezoid): 0.0
#   (2nd top of the trapezoid): 80.0
#   (End of the trapezoid): 100.0
#   Interface(Edit parameters in basic (assisted) or expert (manual) mode): ['Basic mode', 'Expert mode']
#   (): 0
#   Auto(Automatically select optimal single-exponential apodization): False
#   Auto(Automatically select optimal Gauss apodization): False
# ...

# %%
with bjason.Document(fn) as doc:
    print(dir(doc), "\n")

    print("mol_items:", len(doc.mol_items), "\n")
    print("mol_data:", len(doc.mol_data), type(doc.mol_data), "\n")
    mol_item = doc.mol_items[0]
    nmr_item = doc.nmr_items[0]
    mol_data = doc.mol_data[0]
    print("\nmol_item:\n")
    print(mol_item)
    print("\nnmr_item:\n")
    print(dir(nmr_item))
# Out:
# ['__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_create_item_elem', 'close', 'copy', 'create_chart_item', 'create_image_data', 'create_image_item', 'create_nmrassignments_table', 'create_nmrmultiplet_report', 'create_nmrmultiplets_table', 'create_nmrparams_table', 'create_nmrpeaks_table', 'create_text_item', 'file_name', 'h5_file', 'image_data', 'is_temporary', 'items', 'items_by_type', 'load', 'mol_data', 'mol_items', 'nmr_data', 'nmr_items', 'page_margin', 'remove', 'text_data']
#
# mol_items: 1
#
# mol_data: 1 <class 'beautifuljason.data.Molecule.List'>
#
#
# mol_item:
#
# ...

# %%
mol_data.atoms._len
# Out:
# 0

# %%
type(mol_data)
# Out:
# beautifuljason.data.Molecule

# %%
list(mol_data.atoms)
# Out:
# []

# %%
print(dir(mol_data.Atom), "\n")
# Out:
# ['List', 'NuclType', 'Type', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', 'bonded_atom_numbers', 'bonded_atoms', 'bonds', 'charge', 'isotope', 'nh', 'type', 'valence', 'x', 'y', 'z']

# %%
dir(mol_data)
# Out:
# ['Atom',
#  'Coupling',
#  'List',
#  'Ring',
#  'Spectrum',
#  'Symmetry',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'atoms',
#  'couplings',
#  'h5_group',
#  'id',
#  'rings',
#  'spectra',
#  'symmetry']

# %%
dir(nmr_item)
# Out:
# ['Annotation',
#  'PlotType2D',
#  'Print1DMode',
#  'Type',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_bool',
#  '_get_color',
#  '_get_font',
#  '_get_number',
#  '_set_bool',
#  '_set_color',
#  '_set_font',
#  '_set_number',
#  'active_bold',
#  'annotations',
#  'antialiasing',
#  'color_cont',
#  'create',
#  'floor',
#  'h5_group',
#  'has_x_extra_ticks',
#  'has_y_extra_ticks',
#  'header',
#  'header_font',
#  'id',
#  'integral_curve_color',
#  'integral_label_v_shift',
#  'j_tree_label_font',
#  'linked_ids',
# ...

# %%
mol_item.mol_data()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 mol_item.mol_data()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/beautifuljason/graphics.py:2934, in MoleculeGraphicsItem.mol_data(self, id)
#    2924 def mol_data(self, id: int | str = 0) -> data.Molecule:
#    2925     """
#    2926     .. versionadded:: 1.1.0
#    2927
#    (...)
#    2932
#    2933     """
# -> 2934     mols = self.mol_data_list
#    2935     if isinstance(id, int) or str(id).isnumeric():
#    2936         id = int(id)
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/beautifuljason/graphics.py:2918, in MoleculeGraphicsItem.mol_data_list(self)
#    2910 """
#    2911 .. versionadded:: 1.1.0
#    2912
#    (...)
#    2915
#    2916 """
#    2917 result = []
# -> 2918 for mol_draw_item in self.items:
# ...

# %%
dir(mol_item)
# Out:
# ['Annotation',
#  'DrawItem',
#  'DrawStyle',
#  'EditMode',
#  'Editor',
#  'Geometry',
#  'Transform',
#  'Type',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_color',
#  '_set_color',
#  'active_atom_type',
#  'active_bond_type',
#  'annotations',
#  'browse_edit_mode',
#  'create',
#  'draw_style',
#  'editor',
#  'geometry',
#  'h5_group',
#  'id',
#  'items',
#  'linked_ids',
#  'mol_data',
#  'mol_data_list',
#  'parent_item_id',
#  'pos',
#  'rotation',
#  'size',
#  'type',
#  'user_edit_mode',
#  'z_value']

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument'].keys())
# Out:
# <KeysViewHDF5 ['General', 'Items', 'Molecules', 'NMR']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR'].keys())
# Out:
# <KeysViewHDF5 ['NMRData']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData'].keys())
# Out:
# <KeysViewHDF5 ['0', '1', '2', '3', '4', '5']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0'].keys())
# Out:
# <KeysViewHDF5 ['DataPoints', 'Display', 'Multiplets_Integrals', 'Peaks', 'ProcessingTemplate', 'RawData', 'SimulationParameters', 'SpecInfo']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument/NMR/NMRData/0/Peaks'].keys())
# Out:
# <KeysViewHDF5 []>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList'].keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 with h5py.File(fn, "r+") as hf:
# ----> 2     print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList'].keys())
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 with h5py.File(fn, "r+") as hf:
# ----> 2     print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList'])
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs.keys())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 with h5py.File(fn, "r+") as hf:
# ----> 2     print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs.keys())
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs['Pos'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 with h5py.File(fn, "r+") as hf:
# ----> 2     print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs['Pos'])
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs['Height'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 with h5py.File(fn, "r+") as hf:
# ----> 2     print(hf['JasonDocument']['NMR']['NMRData']['0']['Peaks']['PeakList']['0'].attrs['Height'])
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/opt/anaconda3/envs/py313/lib/python3.13/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# ...

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['SpecInfo'].attrs.keys() )
# Out:
# <KeysViewHDF5 ['Arrayed', 'AutoPeakType', 'AutoProcessingMode', 'AutoProcessingMode.str', 'ExperimentType', 'ExperimentType.str', 'OrigFileFormat', 'OrigFileFormat.str', 'OrigFilename', 'OrigFilename.filename.str', 'OrigFilename.filepath.str', 'PulseProgram', 'SW', 'SpectrometerFrequencies', 'SpectrumRef', 'SpectrumType', 'SpectrumTypeExt', 'SpectrumTypeExt.strs', 'Title', 'appliedPh0', 'appliedPh1']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['SpecInfo'].attrs['PulseProgram'] )
# Out:
# b'zg'

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['NMR']['NMRData']['0']['SpecInfo'].keys(
# Out:
#   Cell In[31], line 2
#     print(hf['JasonDocument']['NMR']['NMRData']['0']['SpecInfo'].keys(
#                                                                       ^
# _IncompleteInputError: incomplete input

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Items'].keys())
# Out:
# <KeysViewHDF5 ['0', '1', '2', '3', '4', '5', '6']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Items']['0'].keys())
# Out:
# <KeysViewHDF5 ['BackGroundBrush', 'BorderPen', 'NMRPlot']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules'].keys())
# Out:
# <KeysViewHDF5 ['Molecules', 'SpecData']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules'].keys())
# Out:
# <KeysViewHDF5 ['0']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['SpecData'].keys())
# Out:
# <KeysViewHDF5 ['Data']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['SpecData']['Data'].keys())
# Out:
# <KeysViewHDF5 ['NMR']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['SpecData']['Data']['NMR'].keys())
# Out:
# <KeysViewHDF5 ['1D', '2D', 'Merged1D', 'Merged2D']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0'].keys())
# Out:
# <KeysViewHDF5 ['Atoms', 'NMRData', 'Rings', 'Symmetry']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['Atoms'].keys())
# Out:
# <KeysViewHDF5 ['0', '1', '10', '11', '12', '13', '2', '3', '4', '5', '6', '7', '8', '9']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['Atoms']['10'])
# Out:
# <HDF5 group "/JasonDocument/Molecules/Molecules/0/Atoms/10" (0 members)>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData'].keys())
# Out:
# <KeysViewHDF5 ['Couplings', 'Spectra']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData']['Spectra'].keys())
# Out:
# <KeysViewHDF5 ['SpectraList']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData']['Spectra']['SpectraList'].keys())
# Out:
# <KeysViewHDF5 ['0', '1']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData']['Spectra']['SpectraList']['1'].keys())
# Out:
# <KeysViewHDF5 ['Shifts']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData']['Spectra']['SpectraList']['1']['Shifts'].keys())
# Out:
# <KeysViewHDF5 ['0', '1', '10', '11', '2', '3', '4', '5', '6', '7', '8', '9']>

# %%
with h5py.File(fn, "r+") as hf:
    print(hf['JasonDocument']['Molecules']['Molecules']['0']['NMRData']['Spectra']['SpectraList']['1']['Shifts']['0'].keys())
# Out:
# <KeysViewHDF5 []>
